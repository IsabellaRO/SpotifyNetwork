# %%
from queue import Queue

from unidecode import unidecode
import networkx as nx
import spotipy #https://spotipy.readthedocs.io/en/latest/
from spotipy.oauth2 import SpotifyClientCredentials
# Out:
# /home/chends/.local/lib/python3.6/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# Charles profile link:
# https://open.spotify.com/user/12167056236?si=BfbG8v9wRsOTnilpjP9ibg
# spotify:user:12167056236:playlist:1ahkvZq6vSkYCmqHiPpLJn
charles_id = '12167056236'

# Jazz playlist link:
# https://open.spotify.com/user/12167056236/playlist/2ek4gj4PDBF4aspnYWfBmC?si=eq_YK6V8SdKiuhu1zj5VPA
# spotify:user:12167056236:playlist:2ek4gj4PDBF4aspnYWfBmC
jazz_id = '2ek4gj4PDBF4aspnYWfBmC'

# Bossa nova playlist link:
# https://open.spotify.com/user/12167056236/playlist/1ahkvZq6vSkYCmqHiPpLJn?si=DQT4XTRYSwWagYejOs34Ew
bossanova_id = '1ahkvZq6vSkYCmqHiPpLJn'

# %%
# client_credentials_manager = SpotifyClientCredentials(client_id='943e4795c796489f9243c6e7c9f64fc7', client_secret='c6c980434cb74acc9a7408e5c99618b1')
# sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# spotify:user:12167056236:playlist:2ek4gj4PDBF4aspnYWfBmC

# %%
# playlists = sp.user_playlists('spotify')
# tracks = user_playlist_tracks(user = 12167056236, playlist_id=2ek4gj4PDBF4aspnYWfBmC?si=j-MSydgGR1O3KgIUea6Yzw)

# %%
client_credentials_manager = SpotifyClientCredentials(client_id='943e4795c796489f9243c6e7c9f64fc7', client_secret='c6c980434cb74acc9a7408e5c99618b1')
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# def calc_feat_dict(results):
#     artists_musics = {}
#     for i, item in enumerate(results['items']):
#         track = item['track']
#         artists_musics[track['artists'][0]['name']] = (track['name'].split(" - ")[0])
#         #print(track['id'])
#         #print("%d: %s - %s" % (i, track['artists'][0]['name'], track['name'].split(" - ")[0]))
#     return artists_musics

def calc_tuple(results):
    artists_musics = []
    for i, item in enumerate(results['items']):
        track = item['track']
        artists_musics.append((track['artists'][0]['id'], track['artists'][0]['name'], track['id'], track['name']))
        #print((track['artists'][0]['name'], (track['name'].split(" - ")[0])))
    return artists_musics

# %%
art_mus = {}

results = sp.user_playlist(user = charles_id, playlist_id = jazz_id, fields = "tracks, next")
tracks = results['tracks']

while tracks['next']: #passa pelos 10 conjuntos de tracks
    tracks = sp.next(tracks)
    data = calc_tuple(tracks)    
    
    #inicializa o dicio com o primeiro artista deste cojunto
    for i in range(len(data)): #rodará 100 vezes
        if data[i][1] not in art_mus.keys(): #trocou artista
            art_mus[data[i][1]] = [data[i][2]]         
        else: #mesmo artista
            art_mus[data[i][1]].append(data[i][2])

artistas = 119
print(art_mus)
# Out:
gZeuWr', '2EMlSUcdqy93jtQPbuqF5N', '0hQ6wmyJ59hAbgj1LRFn5E', '6duVCinWAyR0xNVJVnJtOM', '6M7PA8AkKH3KdRAHIXLOT2', '4N4JwOcpVFBpbX81rdKmmX', '15nHxBxHNyQstfpQG5RTEl', '2onhHrH5oMlzm64p7JNsSo', '5hhDi5Q52KqxSWqtBWEDQy', '5JmkEMahYGCP3j8PrZS7Bm', '12Qp1JmViaK0pICUExABbJ', '7kh8zi34qtKol ...

# %%
art_feats = {}
for artist, songs in art_mus.items():
    if len(songs > 50):
        for song in songs:
            if data[i][1] not in art_feats.keys():
                art_feats[artist] = sp.audio_features(songs)
            else:
                art_feats[artist].append(sp.audio_features(songs))
    else:
        feats = sp.audio_features(songs)
# Out:
# 19
# 39
# 24
# 13
# 18
# 23
# 18
# 17
# 16
# 12
# 1
# 3
# 16
# 35
# 1
# 52
# 12
# 12
# 1
# 42
# 3
# 10
# 36
# 13
# 10
# 10
# 9
# 9
# 1
# 1
# 9
# 1
# 13
# 10
# 2
# 2
# 2
# 12
# 9
# 12
# 31
# 8
# 1
# 12
# 6
# 1
# 11
# 1
# 1
# 10
# 1
# 1
# 1
# 4
# 1
# 23
# 3
# 13
# 1
# 1
# 12
# 1
# 1
# 1
# 4
# 1
# 1
# 1
# 1
# 1
# 1
# 3
# 1
# 13
# 53
# 1
# 11
# 11
# 22
# 1
# 1
# 12
# 1
# 1
# 1
# 2
# 14
# 12
# 12
# 12
# 1
# 11
# 2
# 1
# 1
# 24
# 1
# 1
# 1
# 1
# 1
# 3
# 10
# 1
# 2
# 1
# 1
# 2
# 1
# 3
# 11
# 1
# 1
# 1
# 1
# 1
# 1
# 11
# 1

# %%
sp.audio_features(art_mus['Shorty Rogers'])
# Out:
# [{'acousticness': 0.65,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eFl80yr1Q8uOpCK2MqVVP',
#   'danceability': 0.3,
#   'duration_ms': 137413,
#   'energy': 0.568,
#   'id': '7eFl80yr1Q8uOpCK2MqVVP',
#   'instrumentalness': 1.36e-05,
#   'key': 4,
#   'liveness': 0.279,
#   'loudness': -9.953,
#   'mode': 0,
#   'speechiness': 0.0328,
#   'tempo': 173.501,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7eFl80yr1Q8uOpCK2MqVVP',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7eFl80yr1Q8uOpCK2MqVVP',
#   'valence': 0.792},
#  {'acousticness': 0.385,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AH2V817mRZTrPABae4upz',
#   'danceability': 0.572,
#   'duration_ms': 175427,
#   'energy': 0.463,
#   'id': '4AH2V817mRZTrPABae4upz',
#   'instrumentalness': 0.000638,
#   'key': 8,
#   'liveness': 0.399,
#   'loudness': -10.298,
#   'mode': 1,
#   'speechiness': 0.0365,
#   'tempo': 105.302,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4AH2V817mRZTrPABae4upz',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4AH2V817mRZTrPABae4upz',
#   'valence': 0.694},
#  {'acousticness': 0.57,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nHqWtiqYnCggjsBeTvc7t',
#   'danceability': 0.582,
#   'duration_ms': 175213,
#   'energy': 0.477,
#   'id': '5nHqWtiqYnCggjsBeTvc7t',
#   'instrumentalness': 0.312,
#   'key': 1,
#   'liveness': 0.0791,
#   'loudness': -11.628,
#   'mode': 1,
#   'speechiness': 0.178,
#   'tempo': 123.192,
#   'time_signature': 5,
#   'track_href': 'https://api.spotify.com/v1/tracks/5nHqWtiqYnCggjsBeTvc7t',
#   'type': 'audio_features',
#   'uri': 'spotify:track:5nHqWtiqYnCggjsBeTvc7t',
#   'valence': 0.735},
#  {'acousticness': 0.207,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/084CU56jKdwuOV3p4jDMJh',
#   'danceability': 0.535,
#   'duration_ms': 303333,
#   'energy': 0.384,
#   'id': '084CU56jKdwuOV3p4jDMJh',
#   'instrumentalness': 3.13e-05,
#   'key': 5,
#   'liveness': 0.188,
#   'loudness': -12.434,
#   'mode': 1,
#   'speechiness': 0.0342,
#   'tempo': 95.012,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/084CU56jKdwuOV3p4jDMJh',
#   'type': 'audio_features',
#   'uri': 'spotify:track:084CU56jKdwuOV3p4jDMJh',
#   'valence': 0.722},
#  {'acousticness': 0.105,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CFiMlBahoknsuP9oo84zO',
#   'danceability': 0.496,
#   'duration_ms': 245920,
#   'energy': 0.621,
#   'id': '7CFiMlBahoknsuP9oo84zO',
#   'instrumentalness': 0.00956,
#   'key': 5,
#   'liveness': 0.122,
#   'loudness': -10.646,
#   'mode': 1,
#   'speechiness': 0.0366,
#   'tempo': 79.762,
#   'time_signature': 3,
#   'track_href': 'https://api.spotify.com/v1/tracks/7CFiMlBahoknsuP9oo84zO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7CFiMlBahoknsuP9oo84zO',
#   'valence': 0.639},
#  {'acousticness': 0.278,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dEvMRtPhuEXWHW1bBNpPD',
#   'danceability': 0.603,
#   'duration_ms': 184560,
#   'energy': 0.531,
#   'id': '1dEvMRtPhuEXWHW1bBNpPD',
#   'instrumentalness': 2.64e-05,
#   'key': 8,
#   'liveness': 0.0367,
#   'loudness': -10.838,
#   'mode': 1,
#   'speechiness': 0.0419,
#   'tempo': 105.283,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1dEvMRtPhuEXWHW1bBNpPD',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1dEvMRtPhuEXWHW1bBNpPD',
#   'valence': 0.896},
#  {'acousticness': 0.2,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0jN00EUhWfrYytfKP7VtJm',
#   'danceability': 0.404,
#   'duration_ms': 151413,
#   'energy': 0.482,
#   'id': '0jN00EUhWfrYytfKP7VtJm',
#   'instrumentalness': 0.00386,
#   'key': 7,
#   'liveness': 0.358,
#   'loudness': -11.91,
#   'mode': 0,
#   'speechiness': 0.0296,
#   'tempo': 78.495,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/0jN00EUhWfrYytfKP7VtJm',
#   'type': 'audio_features',
#   'uri': 'spotify:track:0jN00EUhWfrYytfKP7VtJm',
#   'valence': 0.554},
#  {'acousticness': 0.341,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ruvTFooRENXdwAPA0z1io',
#   'danceability': 0.537,
#   'duration_ms': 203093,
#   'energy': 0.521,
#   'id': '7ruvTFooRENXdwAPA0z1io',
#   'instrumentalness': 0.0411,
#   'key': 7,
#   'liveness': 0.129,
#   'loudness': -11.807,
#   'mode': 1,
#   'speechiness': 0.0546,
#   'tempo': 123.932,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/7ruvTFooRENXdwAPA0z1io',
#   'type': 'audio_features',
#   'uri': 'spotify:track:7ruvTFooRENXdwAPA0z1io',
#   'valence': 0.803},
#  {'acousticness': 0.285,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/03DGhW3ZxBZCJyyPwKKwGw',
#   'danceability': 0.523,
#   'duration_ms': 107973,
#   'energy': 0.438,
#   'id': '03DGhW3ZxBZCJyyPwKKwGw',
#   'instrumentalness': 1.97e-05,
#   'key': 7,
#   'liveness': 0.108,
#   'loudness': -11.537,
#   'mode': 1,
#   'speechiness': 0.0405,
#   'tempo': 81.257,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/03DGhW3ZxBZCJyyPwKKwGw',
#   'type': 'audio_features',
#   'uri': 'spotify:track:03DGhW3ZxBZCJyyPwKKwGw',
#   'valence': 0.896},
#  {'acousticness': 0.178,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ILVFqII1kO4lolYLvkl5G',
#   'danceability': 0.612,
#   'duration_ms': 145507,
#   'energy': 0.645,
#   'id': '6ILVFqII1kO4lolYLvkl5G',
#   'instrumentalness': 0.62,
#   'key': 5,
#   'liveness': 0.297,
#   'loudness': -10.312,
#   'mode': 1,
#   'speechiness': 0.0335,
#   'tempo': 102.108,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6ILVFqII1kO4lolYLvkl5G',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6ILVFqII1kO4lolYLvkl5G',
#   'valence': 0.799},
#  {'acousticness': 0.295,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35FFgvQKFpRgNqm6EKVo3l',
#   'danceability': 0.631,
#   'duration_ms': 127267,
#   'energy': 0.503,
#   'id': '35FFgvQKFpRgNqm6EKVo3l',
#   'instrumentalness': 1.63e-05,
#   'key': 7,
#   'liveness': 0.264,
#   'loudness': -14.192,
#   'mode': 0,
#   'speechiness': 0.0361,
#   'tempo': 117.014,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/35FFgvQKFpRgNqm6EKVo3l',
#   'type': 'audio_features',
#   'uri': 'spotify:track:35FFgvQKFpRgNqm6EKVo3l',
#   'valence': 0.815},
#  {'acousticness': 0.704,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Ue41Ts5phLmsdVAetfVMU',
#   'danceability': 0.637,
#   'duration_ms': 175427,
#   'energy': 0.342,
#   'id': '3Ue41Ts5phLmsdVAetfVMU',
#   'instrumentalness': 0.00307,
#   'key': 8,
#   'liveness': 0.405,
#   'loudness': -13.129,
#   'mode': 1,
#   'speechiness': 0.0374,
#   'tempo': 105.216,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/3Ue41Ts5phLmsdVAetfVMU',
#   'type': 'audio_features',
#   'uri': 'spotify:track:3Ue41Ts5phLmsdVAetfVMU',
#   'valence': 0.725},
#  {'acousticness': 0.734,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/22rjKEQJZOUwx7hfLnq5UJ',
#   'danceability': 0.577,
#   'duration_ms': 175213,
#   'energy': 0.358,
#   'id': '22rjKEQJZOUwx7hfLnq5UJ',
#   'instrumentalness': 0.24,
#   'key': 1,
#   'liveness': 0.0893,
#   'loudness': -14.881,
#   'mode': 1,
#   'speechiness': 0.314,
#   'tempo': 97.6,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/22rjKEQJZOUwx7hfLnq5UJ',
#   'type': 'audio_features',
#   'uri': 'spotify:track:22rjKEQJZOUwx7hfLnq5UJ',
#   'valence': 0.705},
#  {'acousticness': 0.367,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YJ4Okkqpb3Ajx01ZJxnwO',
#   'danceability': 0.601,
#   'duration_ms': 303333,
#   'energy': 0.301,
#   'id': '4YJ4Okkqpb3Ajx01ZJxnwO',
#   'instrumentalness': 2.32e-06,
#   'key': 5,
#   'liveness': 0.192,
#   'loudness': -14.985,
#   'mode': 1,
#   'speechiness': 0.0385,
#   'tempo': 94.795,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/4YJ4Okkqpb3Ajx01ZJxnwO',
#   'type': 'audio_features',
#   'uri': 'spotify:track:4YJ4Okkqpb3Ajx01ZJxnwO',
#   'valence': 0.784},
#  {'acousticness': 0.55,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1BdBPEGH6b76XQG5SFaaFz',
#   'danceability': 0.674,
#   'duration_ms': 184560,
#   'energy': 0.417,
#   'id': '1BdBPEGH6b76XQG5SFaaFz',
#   'instrumentalness': 7.44e-06,
#   'key': 8,
#   'liveness': 0.0402,
#   'loudness': -13.465,
#   'mode': 1,
#   'speechiness': 0.0473,
#   'tempo': 105.364,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1BdBPEGH6b76XQG5SFaaFz',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1BdBPEGH6b76XQG5SFaaFz',
#   'valence': 0.836},
#  {'acousticness': 0.346,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1plvAv8LKXE2Qa9IMGlcC1',
#   'danceability': 0.46,
#   'duration_ms': 151413,
#   'energy': 0.363,
#   'id': '1plvAv8LKXE2Qa9IMGlcC1',
#   'instrumentalness': 0.000653,
#   'key': 3,
#   'liveness': 0.197,
#   'loudness': -14.815,
#   'mode': 1,
#   'speechiness': 0.0293,
#   'tempo': 158.825,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/1plvAv8LKXE2Qa9IMGlcC1',
#   'type': 'audio_features',
#   'uri': 'spotify:track:1plvAv8LKXE2Qa9IMGlcC1',
#   'valence': 0.642},
#  {'acousticness': 0.551,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VBdWuqKbG2mL3ky4RdFb5',
#   'danceability': 0.576,
#   'duration_ms': 203093,
#   'energy': 0.368,
#   'id': '2VBdWuqKbG2mL3ky4RdFb5',
#   'instrumentalness': 0.0493,
#   'key': 7,
#   'liveness': 0.122,
#   'loudness': -15.136,
#   'mode': 1,
#   'speechiness': 0.0598,
#   'tempo': 123.688,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2VBdWuqKbG2mL3ky4RdFb5',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2VBdWuqKbG2mL3ky4RdFb5',
#   'valence': 0.747},
#  {'acousticness': 0.442,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hXQhvqb5qqYZKBkEGBRvx',
#   'danceability': 0.586,
#   'duration_ms': 107973,
#   'energy': 0.338,
#   'id': '6hXQhvqb5qqYZKBkEGBRvx',
#   'instrumentalness': 6.86e-06,
#   'key': 7,
#   'liveness': 0.119,
#   'loudness': -14.114,
#   'mode': 1,
#   'speechiness': 0.0473,
#   'tempo': 82.075,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/6hXQhvqb5qqYZKBkEGBRvx',
#   'type': 'audio_features',
#   'uri': 'spotify:track:6hXQhvqb5qqYZKBkEGBRvx',
#   'valence': 0.861},
#  {'acousticness': 0.55,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2H5C4BTNjBplzW9Dxclvr4',
#   'danceability': 0.649,
#   'duration_ms': 145507,
#   'energy': 0.526,
#   'id': '2H5C4BTNjBplzW9Dxclvr4',
#   'instrumentalness': 0.237,
#   'key': 5,
#   'liveness': 0.279,
#   'loudness': -12.618,
#   'mode': 1,
#   'speechiness': 0.0401,
#   'tempo': 102.033,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/2H5C4BTNjBplzW9Dxclvr4',
#   'type': 'audio_features',
#   'uri': 'spotify:track:2H5C4BTNjBplzW9Dxclvr4',
#   'valence': 0.871}]
